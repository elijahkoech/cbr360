# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data2.csv")
df.columns = [i.replace(" ", "_").lower() for i in df.columns]
df.head()
# Out:
#   date_uploaded_date country        product_group registration_date_month  \
# 0         2025-09-01   Kenya      SHS Entry-Level                 2025-02
# 1         2025-09-01   Kenya      SHS Entry-Level                 2022-08
# 2         2025-09-01   Kenya  SHS with TV Upgrade                 2021-08
# 3         2025-09-01  Uganda      SHS Entry-Level                 2022-05
# 4         2025-09-01   Kenya             Lanterns                 2025-03
#
#    predicted_frr_updated  count
# 0               0.860431   6241
# 1               0.845198   6377
# 2               0.741954   1250
# 3               0.717826   1012
# 4               0.876410   4931

# %%
df.date_uploaded_date.unique()
# Out:
# array(['2025-09-01', '2025-08-01', '2025-07-01', '2025-06-01',
#        '2025-05-01', '2025-04-01', '2025-03-04', '2025-02-01',
#        '2025-01-02', '2024-12-01', '2024-11-01', '2024-10-01',
#        '2024-09-02', '2024-08-01', '2024-07-01', '2024-06-01',
#        '2024-05-02', '2024-04-09', '2024-03-01', '2024-02-05',
#        '2024-01-02', '2023-12-05', '2023-11-01', '2023-10-03',
#        '2023-09-05', '2023-08-25', '2023-08-02', '2023-07-31'],
#       dtype=object)

# %%
pivoted = df.pivot_table(
    index=["country", "product_group","registration_date_month"],
    columns="date_uploaded_date",
    values=["predicted_frr_updated", "count"]
).reset_index()

pivoted.columns = [
    "_".join([str(c) for c in col if c])  # join levels with underscore
    for col in pivoted.columns.values
]
pivoted["registration_date_month"] = (
    pd.to_datetime(pivoted["registration_date_month"], format="%Y-%m")
      .dt.to_period("M")
)

# %%
pivoted
# Out:
#      country   product_group registration_date_month  count_2023-07-31  \
# 0      Kenya        Lanterns                 2021-06            3650.0
# 1      Kenya        Lanterns                 2021-07            3767.0
# 2      Kenya        Lanterns                 2021-08            3715.0
# 3      Kenya        Lanterns                 2021-09            3563.0
# 4      Kenya        Lanterns                 2021-10            3709.0
# ...      ...             ...                     ...               ...
# 1622  Zambia  SHS without TV                 2025-03               NaN
# 1623  Zambia  SHS without TV                 2025-04               NaN
# 1624  Zambia  SHS without TV                 2025-05               NaN
# 1625  Zambia  SHS without TV                 2025-06               NaN
# 1626  Zambia  SHS without TV                 2025-07               NaN
#
#       count_2023-08-02  count_2023-08-25  count_2023-09-05  count_2023-10-03  \
# 0               3650.0               NaN            3650.0            3650.0
# 1               3767.0               NaN            3767.0            3767.0
# 2               3715.0               NaN            3715.0            3715.0
# 3               3563.0               NaN            3563.0            3563.0
# 4               3709.0               NaN            3709.0            3709.0
# ...                ...               ...               ...               ...
# 1622               NaN               NaN               NaN               NaN
# 1623               NaN               NaN               NaN               NaN
# 1624               NaN               NaN               NaN               NaN
# 1625               NaN               NaN               NaN               NaN
# 1626               NaN               NaN               NaN               NaN
#
#       count_2023-11-01  count_2023-12-05  ...  \
# 0               3650.0            3650.0  ...
# 1               3767.0            3767.0  ...
# 2               3715.0            3715.0  ...
# 3               3563.0            3563.0  ...
# 4               3709.0            3709.0  ...
# ...                ...               ...  ...
# 1622               NaN               NaN  ...
# 1623               NaN               NaN  ...
# 1624               NaN               NaN  ...
# 1625               NaN               NaN  ...
# 1626               NaN               NaN  ...
#
#       predicted_frr_updated_2024-12-01  predicted_frr_updated_2025-01-02  \
# 0                             0.917024                          0.917095
# 1                             0.917091                          0.917132
# 2                             0.915239                          0.915242
# 3                             0.915242                          0.915316
# 4                             0.918335                          0.918428
# ...                                ...                               ...
# 1622                               NaN                               NaN
# 1623                               NaN                               NaN
# 1624                               NaN                               NaN
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-02-01  predicted_frr_updated_2025-03-04  \
# 0                             0.917100                          0.923682
# 1                             0.917132                          0.923794
# 2                             0.915242                          0.920996
# 3                             0.915312                          0.920970
# 4                             0.918434                          0.923380
# ...                                ...                               ...
# 1622                               NaN                               NaN
# 1623                               NaN                               NaN
# 1624                               NaN                               NaN
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-04-01  predicted_frr_updated_2025-05-01  \
# 0                             0.923682                          0.923681
# 1                             0.923792                          0.923758
# 2                             0.921244                          0.921187
# 3                             0.920973                          0.920939
# 4                             0.923379                          0.923303
# ...                                ...                               ...
# 1622                               NaN                          0.976674
# 1623                               NaN                               NaN
# 1624                               NaN                               NaN
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-06-01  predicted_frr_updated_2025-07-01  \
# 0                             0.923688                          0.923694
# 1                             0.923758                          0.923757
# 2                             0.921184                          0.921187
# 3                             0.920937                          0.920938
# 4                             0.923303                          0.923296
# ...                                ...                               ...
# 1622                          0.979620                          0.985045
# 1623                          0.978405                          0.985699
# 1624                               NaN                          0.986601
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-08-01  predicted_frr_updated_2025-09-01
# 0                             0.921999                          0.922010
# 1                             0.922243                          0.922247
# 2                             0.919908                          0.919909
# 3                             0.919863                          0.919856
# 4                             0.922101                          0.922100
# ...                                ...                               ...
# 1622                          0.985019                          0.987361
# 1623                          0.983102                          0.986009
# 1624                          0.986054                          0.984654
# 1625                          0.971452                          0.979647
# 1626                               NaN                          0.964736
#
# [1627 rows x 58 columns]

# %% [markdown]
# ## Establish Backtesting Checkpoints

# %%
backtestings = np.array([30, 60, 90, 180, 270, 360, 450, 540, 630, 720], dtype=int)
months = backtestings // 30
current_month = pd.Timestamp.today().to_period("M")

# %%
# vectorized subtraction
backtesting_month_current = current_month - (months + 1)
backtesting_month_prev = current_month - (months + 2)

print(backtesting_month_current)

data = {
    "Months": months,
    "backtesting_month_current": backtesting_month_current,
    "backtesting_month_prev": backtesting_month_prev,
    "backtesting_shift": backtestings
}
backtestings_df = pd.DataFrame(data)
# Out:
# [Period('2025-07', 'M') Period('2025-06', 'M') Period('2025-05', 'M')
#  Period('2025-02', 'M') Period('2024-11', 'M') Period('2024-08', 'M')
#  Period('2024-05', 'M') Period('2024-02', 'M') Period('2023-11', 'M')
#  Period('2023-08', 'M')]

# %%
backtestings_df
# Out:
#    Months backtesting_month_current backtesting_month_prev  backtesting_shift
# 0       1                   2025-07                2025-06                 30
# 1       2                   2025-06                2025-05                 60
# 2       3                   2025-05                2025-04                 90
# 3       6                   2025-02                2025-01                180
# 4       9                   2024-11                2024-10                270
# 5      12                   2024-08                2024-07                360
# 6      15                   2024-05                2024-04                450
# 7      18                   2024-02                2024-01                540
# 8      21                   2023-11                2023-10                630
# 9      24                   2023-08                2023-07                720

# %%
discrepancies = pd.merge(left=pivoted, right=backtestings_df, left_on="registration_date_month", right_on="backtesting_month_current", how="left")
discrepancies["backtesting_shift"] = discrepancies["backtesting_shift"].astype("Int64")

# %%
discrepancies
# Out:
#      country   product_group registration_date_month  count_2023-07-31  \
# 0      Kenya        Lanterns                 2021-06            3650.0
# 1      Kenya        Lanterns                 2021-07            3767.0
# 2      Kenya        Lanterns                 2021-08            3715.0
# 3      Kenya        Lanterns                 2021-09            3563.0
# 4      Kenya        Lanterns                 2021-10            3709.0
# ...      ...             ...                     ...               ...
# 1622  Zambia  SHS without TV                 2025-03               NaN
# 1623  Zambia  SHS without TV                 2025-04               NaN
# 1624  Zambia  SHS without TV                 2025-05               NaN
# 1625  Zambia  SHS without TV                 2025-06               NaN
# 1626  Zambia  SHS without TV                 2025-07               NaN
#
#       count_2023-08-02  count_2023-08-25  count_2023-09-05  count_2023-10-03  \
# 0               3650.0               NaN            3650.0            3650.0
# 1               3767.0               NaN            3767.0            3767.0
# 2               3715.0               NaN            3715.0            3715.0
# 3               3563.0               NaN            3563.0            3563.0
# 4               3709.0               NaN            3709.0            3709.0
# ...                ...               ...               ...               ...
# 1622               NaN               NaN               NaN               NaN
# 1623               NaN               NaN               NaN               NaN
# 1624               NaN               NaN               NaN               NaN
# 1625               NaN               NaN               NaN               NaN
# 1626               NaN               NaN               NaN               NaN
#
#       count_2023-11-01  count_2023-12-05  ...  \
# 0               3650.0            3650.0  ...
# 1               3767.0            3767.0  ...
# 2               3715.0            3715.0  ...
# 3               3563.0            3563.0  ...
# 4               3709.0            3709.0  ...
# ...                ...               ...  ...
# 1622               NaN               NaN  ...
# 1623               NaN               NaN  ...
# 1624               NaN               NaN  ...
# 1625               NaN               NaN  ...
# 1626               NaN               NaN  ...
#
#       predicted_frr_updated_2025-04-01  predicted_frr_updated_2025-05-01  \
# 0                             0.923682                          0.923681
# 1                             0.923792                          0.923758
# 2                             0.921244                          0.921187
# 3                             0.920973                          0.920939
# 4                             0.923379                          0.923303
# ...                                ...                               ...
# 1622                               NaN                          0.976674
# 1623                               NaN                               NaN
# 1624                               NaN                               NaN
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-06-01  predicted_frr_updated_2025-07-01  \
# 0                             0.923688                          0.923694
# 1                             0.923758                          0.923757
# 2                             0.921184                          0.921187
# 3                             0.920937                          0.920938
# 4                             0.923303                          0.923296
# ...                                ...                               ...
# 1622                          0.979620                          0.985045
# 1623                          0.978405                          0.985699
# 1624                               NaN                          0.986601
# 1625                               NaN                               NaN
# 1626                               NaN                               NaN
#
#       predicted_frr_updated_2025-08-01  predicted_frr_updated_2025-09-01  \
# 0                             0.921999                          0.922010
# 1                             0.922243                          0.922247
# 2                             0.919908                          0.919909
# 3                             0.919863                          0.919856
# 4                             0.922101                          0.922100
# ...                                ...                               ...
# 1622                          0.985019                          0.987361
# 1623                          0.983102                          0.986009
# 1624                          0.986054                          0.984654
# 1625                          0.971452                          0.979647
# 1626                               NaN                          0.964736
#
#       Months  backtesting_month_current  backtesting_month_prev  \
# 0        NaN                        NaT                     NaT
# 1        NaN                        NaT                     NaT
# 2        NaN                        NaT                     NaT
# 3        NaN                        NaT                     NaT
# 4        NaN                        NaT                     NaT
# ...      ...                        ...                     ...
# 1622     NaN                        NaT                     NaT
# 1623     NaN                        NaT                     NaT
# 1624     3.0                    2025-05                 2025-04
# 1625     2.0                    2025-06                 2025-05
# 1626     1.0                    2025-07                 2025-06
#
#       backtesting_shift
# 0                  <NA>
# 1                  <NA>
# 2                  <NA>
# 3                  <NA>
# 4                  <NA>
# ...                 ...
# 1622               <NA>
# 1623               <NA>
# 1624                 90
# 1625                 60
# 1626                 30
#
# [1627 rows x 62 columns]

# %%
discrepancies["diff"] = (discrepancies["predicted_frr_updated_2025-09-01"] - discrepancies["predicted_frr_updated_2025-08-01"]).round(4)*100

# backtesting_reasons = {
#   30: "Due to backtesting shift to 30",
#   60: "Due to backtesting shift from 30 to 60",
#   90: "Due to backtesting shift from 60 to 90",
#   180: "Due to backtesting shift from 90 to 180",
#   270: "Due to backtesting shift from 180 to 270",
#   360: "Due to backtesting shift from 270 to 360",
#   450: "Due to backtesting shift from 360 to 450",
#   540: "Due to backtesting shift from 450 to 540",
#   630: "Due to backtesting shift from 540 to 630",
#   720: "Due to backtesting shift from 630 to 720"
# }
# discrepancies = discrepancies.copy()
# discrepancies["reason"] = (
#     discrepancies["backtesting_shift"].map(backtesting_reasons)
#     .where(discrepancies["diff"].abs() > 0.75)
# )
# discrepancies.head()

# %%
discrepancies_df = discrepancies[discrepancies.backtesting_shift.isin([360, 450, 540, 630, 720])]

# %%
discrepancies_df[(discrepancies_df.product_group=="Lanterns") & (discrepancies_df.country=="Kenya")]
# Out:
#    country product_group registration_date_month  count_2023-07-31  \
# 26   Kenya      Lanterns                 2023-08               NaN
# 29   Kenya      Lanterns                 2023-11               NaN
# 32   Kenya      Lanterns                 2024-02               NaN
# 35   Kenya      Lanterns                 2024-05               NaN
# 38   Kenya      Lanterns                 2024-08               NaN
#
#     count_2023-08-02  count_2023-08-25  count_2023-09-05  count_2023-10-03  \
# 26               NaN               NaN               NaN            3889.0
# 29               NaN               NaN               NaN               NaN
# 32               NaN               NaN               NaN               NaN
# 35               NaN               NaN               NaN               NaN
# 38               NaN               NaN               NaN               NaN
#
#     count_2023-11-01  count_2023-12-05  ...  predicted_frr_updated_2025-05-01  \
# 26            3889.0            3889.0  ...                          0.897830
# 29               NaN               NaN  ...                          0.887175
# 32               NaN               NaN  ...                          0.894796
# 35               NaN               NaN  ...                          0.880080
# 38               NaN               NaN  ...                          0.882770
#
#     predicted_frr_updated_2025-06-01  predicted_frr_updated_2025-07-01  \
# 26                          0.897294                          0.897300
# 29                          0.877889                          0.877889
# 32                          0.880007                          0.880007
# 35                          0.884859                          0.884857
# 38                          0.878815                          0.878416
#
#     predicted_frr_updated_2025-08-01  predicted_frr_updated_2025-09-01  \
# 26                          0.898212                          0.895809
# 29                          0.878588                          0.878636
# 32                          0.880007                          0.866933
# 35                          0.884857                          0.869871
# 38                          0.877977                          0.885024
#
#     Months  backtesting_month_current  backtesting_month_prev  \
# 26    24.0                    2023-08                 2023-07
# 29    21.0                    2023-11                 2023-10
# 32    18.0                    2024-02                 2024-01
# 35    15.0                    2024-05                 2024-04
# 38    12.0                    2024-08                 2024-07
#
#     backtesting_shift  diff
# 26                720 -0.24
# 29                630  0.00
# 32                540 -1.31
# 35                450 -1.50
# 38                360  0.70
#
# [5 rows x 63 columns]

# %%
discrepancies_summary = (
    discrepancies_df
    .groupby(["country", "product_group"])
    .agg(
        total_records=("diff", "size"),
        count_average=("count_2025-09-01", lambda x: int(x.mean())),
        count_median=("count_2025-09-01", lambda x: int(x.median())),
        mean_diff=("diff", lambda x: x.mean().round(2)),
        discrepancies_75=("diff", lambda x: (x.abs() > 0.75).sum())
    )
    .reset_index()
)

discrepancies_summary
# Out:
#      country            product_group  total_records  count_average  \
# 0      Kenya                 Lanterns              5           4682
# 1      Kenya                   Phones              5           3603
# 2      Kenya          SHS Entry-Level              5           4724
# 3      Kenya  SHS Entry-Level Upgrade              5            531
# 4      Kenya              SHS with TV              5            728
# 5      Kenya      SHS with TV Upgrade              5            498
# 6      Kenya           SHS without TV              5           1939
# 7     Malawi                 Lanterns              3            174
# 8     Malawi          SHS Entry-Level              5            263
# 9     Malawi              SHS with TV              5             25
# 10    Malawi           SHS without TV              5             80
# 11   Nigeria                   Phones              5           1343
# 12   Nigeria          SHS Entry-Level              5           2404
# 13   Nigeria              SHS with TV              5           1678
# 14   Nigeria      SHS with TV Upgrade              5             42
# 15   Nigeria           SHS without TV              5            973
# 16  Tanzania                 Lanterns              5           1570
# 17  Tanzania                   Phones              5            596
# 18  Tanzania          SHS Entry-Level              5           2583
# 19  Tanzania  SHS Entry-Level Upgrade              5              4
# 20  Tanzania              SHS with TV              5            261
# 21  Tanzania      SHS with TV Upgrade              5            197
# 22  Tanzania           SHS without TV              5            859
# 23      Togo          SHS Entry-Level              5            340
# 24      Togo              SHS with TV              3             64
# 25      Togo           SHS without TV              1             15
# 26    Uganda                 Lanterns              5            228
# 27    Uganda                   Phones              4             12
# 28    Uganda          SHS Entry-Level              5            433
# 29    Uganda  SHS Entry-Level Upgrade              2              3
# 30    Uganda              SHS with TV              5             20
# 31    Uganda      SHS with TV Upgrade              5             19
# 32    Uganda           SHS without TV              5             39
# 33    Zambia                 Lanterns              4            324
# 34    Zambia                   Phones              2              9
# 35    Zambia          SHS Entry-Level              5            804
# 36    Zambia  SHS Entry-Level Upgrade              5             16
# 37    Zambia              SHS with TV              5             99
# 38    Zambia      SHS with TV Upgrade              5             74
# 39    Zambia           SHS without TV              5            128
#
#     count_median  mean_diff  discrepancies_75
# 0           4665      -0.47                 2
# 1           2830      -0.21                 1
# 2           4637      -0.38                 3
# 3            434      -0.25                 0
# 4            665      -0.74                 3
# 5            522      -0.11                 1
# 6           1844      -0.86                 4
# 7            119       0.00                 0
# 8            239      -0.08                 0
# 9             25      -0.24                 2
# 10            76      -0.07                 0
# 11          1320      -0.11                 0
# 12          2431      -0.22                 1
# 13          1746      -0.26                 1
# 14            33       0.02                 0
# 15          1028      -0.23                 0
# 16          1614      -0.65                 2
# 17           362      -0.33                 2
# 18          2589      -0.44                 3
# 19             4      -0.87                 3
# 20           162      -0.29                 1
# 21           192      -0.51                 2
# 22           875      -0.52                 5
# 23           343       0.19                 4
# 24            38       1.22                 3
# 25            15      -3.51                 1
# 26           219      -0.77                 4
# 27             7      -3.08                 3
# 28           401      -0.92                 4
# 29             3       2.61                 2
# 30            23      -1.09                 5
# 31            19      -0.65                 2
# 32            37      -0.62                 3
# 33           305       0.24                 0
# 34             9      -1.66                 1
# 35           772       0.07                 0
# 36            17       0.30                 1
# 37            98      -0.08                 1
# 38            66      -0.13                 1
# 39            64       0.01                 0
