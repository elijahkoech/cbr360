# %%
import lightgbm
import numpy as np
import pandas as pd

# %% [markdown]
# ## Generate Predictions Func

# %%
def generate_predictions(df_kpi, date_uploaded, model_object, backtesting_limit=360):
    df_kpi = df_kpi[df_kpi['backtesting_limit'] == backtesting_limit].reset_index().drop(columns = 'index')
    col_720 = [col for col in df_kpi.columns if '_720' in col]
    col_630 = [col for col in df_kpi.columns if '_630' in col]
    col_540 = [col for col in df_kpi.columns if '_540' in col]
    col_450 = [col for col in df_kpi.columns if '_450' in col]

    col_450_540_630_720 = col_720+col_630+col_540+col_450
    col_540_630_720 = col_720+col_630+col_540
    col_630_720 = col_720+col_630

    df_kpi.loc[(df_kpi['cohort_age_backtesting']==360),col_450_540_630_720] = np.nan
    df_kpi.loc[(df_kpi['cohort_age_backtesting']==450),col_540_630_720] = np.nan
    df_kpi.loc[(df_kpi['cohort_age_backtesting']==540),col_630_720] = np.nan
    df_kpi.loc[(df_kpi['cohort_age_backtesting']==630),col_720] = np.nan
    
    preds = model_object.predict(df_kpi[model_object.feature_name()])
    df_kpi["predictions"] = preds
    
    for months in [360, 450, 540, 630, 720]:
        frr_col = f"frr_{months}"
        mask = (df_kpi["age_in_months"] == months) & (df_kpi[frr_col] > df_kpi["predictions"])
        df_kpi.loc[mask, "predictions"] = df_kpi[frr_col]

    df_kpi["predictions"] = df_kpi["predictions"].clip(lower=0, upper=1)
    df_kpi["date_uploaded"] = date_uploaded
    df_kpi["date_uploaded"] = pd.to_datetime(df_kpi["date_uploaded"], format="%Y-%m-%d")
    df_kpi["reg_month"] = pd.to_datetime(df_kpi["reg_month"], format="%Y-%m")
    df_kpi["predicted_revenue_3_years_50"] = np.round(df_kpi['predictions']*df_kpi['total_follow_on_revenue_current_usd'],2)
    return df_kpi

def expand_rows(df, horizon_steps=[360, 450, 540, 630, 720]):
    df_rep = df.loc[df.index.repeat(len(horizon_steps))].copy()
    df_rep["current_horizon"] = np.tile(horizon_steps, len(df))
    df_rep = df_rep[df_rep["current_horizon"] <= df_rep["cohort_age_backtesting"]]

    feature_cols = [c for c in df.columns if any(c.endswith(f"_{h}") for h in horizon_steps)]
    for col in feature_cols:
        feat_h = int(col.split("_")[-1])
        df_rep.loc[df_rep["current_horizon"] < feat_h, col] = np.nan

    return df_rep.reset_index(drop=True)

import numpy as np
import pandas as pd

def expand_rows2(df, horizon_steps=[360, 450, 540, 630, 720]):
    # Map horizon -> previous horizon
    prev_map = {h: horizon_steps[i-1] if i > 0 else None 
                for i, h in enumerate(horizon_steps)}

    # Current horizons: always keep cohort_age_backtesting
    df_current = df.copy()
    df_current["current_horizon"] = df_current["cohort_age_backtesting"]

    # Previous horizons: map each cohort to its previous step
    df_prev = df.copy()
    df_prev["current_horizon"] = df_prev["cohort_age_backtesting"].map(prev_map)
    df_prev = df_prev.dropna(subset=["current_horizon"])  # drop if no previous exists

    # Combine
    df_rep = pd.concat([df_current, df_prev], ignore_index=True)

    # Mask feature columns
    feature_cols = [c for c in df.columns if any(c.endswith(f"_{h}") for h in horizon_steps)]
    for col in feature_cols:
        feat_h = int(col.split("_")[-1])
        df_rep.loc[df_rep["current_horizon"] < feat_h, col] = np.nan

    return df_rep.reset_index(drop=True)

# %% [markdown]
# ## Load Data

# %%
# model_1 = lightgbm.Booster(model_file = "quantile_regression_360_0.5_days_2025-09-29.txt")
model_1 = lightgbm.Booster(model_file = "../data/quantile_regression_360_0.5_days_2025-02-23.txt")

# %%
kpi_processed_file = '../data/KPIs_data_processed_2025-10-01.csv'
df_kpi = pd.read_csv(kpi_processed_file)
df_kpi_expanded = expand_rows2(df_kpi, horizon_steps=[360, 450, 540, 630, 720])

# %%
# df_kpi_expanded[(df_kpi_expanded.accounts_group=='2023-12_Kenya_Lanterns_Kakamega_Sun King Boom EasyBuy') & (df_kpi_expanded.backtesting_limit==360)]

# %%
# df_kpi_expanded_all = expand_rows(df_kpi, horizon_steps=[360, 450, 540, 630, 720])

# %%
# df_kpi_expanded_all[(df_kpi_expanded_all.accounts_group=='2024-02_Kenya_Lanterns_Kakamega_Sun King Boom EasyBuy') & (df_kpi_expanded_all.backtesting_limit==360)]

# %%
# df_kpi_expanded = expand_rows(df_kpi, horizon_steps=[360, 450, 540, 630, 720])
df_preds_sep = generate_predictions(df_kpi=df_kpi_expanded, date_uploaded="2025-10-01", model_object=model_1, backtesting_limit=360)

kpi_processed_file = '../data/KPIs_data_processed_2025-09-01.csv'
df_kpi = pd.read_csv(kpi_processed_file)
df_kpi_expanded = expand_rows2(df_kpi, horizon_steps=[360, 450, 540, 630, 720])
df_preds_aug = generate_predictions(df_kpi=df_kpi_expanded, date_uploaded="2025-09-01", model_object=model_1, backtesting_limit=360)

df2 = pd.concat([df_preds_sep, df_preds_aug])
print(df2.shape)
df2_copy = df2.copy()
# Out:
# (658501, 93)

# %% [markdown]
# ## Example Data Point

# %%
df2_copy[df2_copy.accounts_group=='2024-02_Kenya_Lanterns_Kakamega_Sun King Boom EasyBuy'].T.tail(40)
# Out:
#                                                 142442               315677  \
# disabled_gt_two_week_rate_90                  0.026873             0.026873
# disabled_gt_two_week_rate_180                 0.056189             0.056189
# disabled_gt_two_week_rate_270                 0.093648             0.093648
# disabled_gt_two_week_rate_360                 0.108306             0.108306
# disabled_gt_two_week_rate_450                 0.143322             0.143322
# disabled_gt_two_week_rate_540                 0.180782                  NaN
# disabled_gt_two_week_rate_630                      NaN                  NaN
# disabled_gt_two_week_rate_720                      NaN                  NaN
# unlocked_rate_30                                   0.0                  0.0
# unlocked_rate_60                                   0.0                  0.0
# unlocked_rate_90                                   0.0                  0.0
# unlocked_rate_180                             0.002443             0.002443
# unlocked_rate_270                             0.004886             0.004886
# unlocked_rate_360                             0.013844             0.013844
# unlocked_rate_450                             0.196254             0.196254
# unlocked_rate_540                             0.394137                  NaN
# unlocked_rate_630                                  NaN                  NaN
# unlocked_rate_720                                  NaN                  NaN
# disabled_rate_30                              0.201954             0.201954
# disabled_rate_60                              0.232085             0.232085
# disabled_rate_90                              0.270358             0.270358
# disabled_rate_180                             0.320847             0.320847
# disabled_rate_270                             0.388436             0.388436
# disabled_rate_360                             0.397394             0.397394
# disabled_rate_450                             0.428339             0.428339
# disabled_rate_540                             0.395765                  NaN
# disabled_rate_630                                  NaN                  NaN
# disabled_rate_720                                  NaN                  NaN
# age_in_months                                       19                   19
# exchange                                        152.85               152.85
# total_follow_on_revenue_usd_cal             65097.0232           65097.0232
# total_follow_on_revenue_usd_final         65097.022396         65097.022396
# avg_upfront_price_usd                              3.0                  3.0
# avg_unlock_price_usd                              56.0                 56.0
# backtesting_limit                                  360                  360
# cohort_age_backtesting                             540                  540
# current_horizon                                  540.0                450.0
# predictions                                   0.888662             0.896705
# date_uploaded                      2025-10-01 00:00:00  2025-10-01 00:00:00
# predicted_revenue_3_years_50                   68380.3             68999.19
#
#                                                 142335               310929
# disabled_gt_two_week_rate_90                  0.026873             0.026873
# disabled_gt_two_week_rate_180                 0.056189             0.056189
# disabled_gt_two_week_rate_270                 0.093648             0.093648
# disabled_gt_two_week_rate_360                 0.108306             0.108306
# disabled_gt_two_week_rate_450                 0.143322             0.143322
# disabled_gt_two_week_rate_540                 0.180782                  NaN
# disabled_gt_two_week_rate_630                      NaN                  NaN
# disabled_gt_two_week_rate_720                      NaN                  NaN
# unlocked_rate_30                                   0.0                  0.0
# unlocked_rate_60                                   0.0                  0.0
# unlocked_rate_90                                   0.0                  0.0
# unlocked_rate_180                             0.002443             0.002443
# unlocked_rate_270                             0.004886             0.004886
# unlocked_rate_360                             0.013844             0.013844
# unlocked_rate_450                             0.196254             0.196254
# unlocked_rate_540                             0.394137                  NaN
# unlocked_rate_630                                  NaN                  NaN
# unlocked_rate_720                                  NaN                  NaN
# disabled_rate_30                              0.201954             0.201954
# disabled_rate_60                              0.232085             0.232085
# disabled_rate_90                              0.270358             0.270358
# disabled_rate_180                             0.320847             0.320847
# disabled_rate_270                             0.388436             0.388436
# disabled_rate_360                             0.397394             0.397394
# disabled_rate_450                             0.428339             0.428339
# disabled_rate_540                             0.395765                  NaN
# disabled_rate_630                                  NaN                  NaN
# disabled_rate_720                                  NaN                  NaN
# age_in_months                                       18                   18
# exchange                                        152.85               152.85
# total_follow_on_revenue_usd_cal             65097.0232           65097.0232
# total_follow_on_revenue_usd_final         65097.022396         65097.022396
# avg_upfront_price_usd                              3.0                  3.0
# avg_unlock_price_usd                              56.0                 56.0
# backtesting_limit                                  360                  360
# cohort_age_backtesting                             540                  540
# current_horizon                                  540.0                450.0
# predictions                                   0.888662             0.896705
# date_uploaded                      2025-09-01 00:00:00  2025-09-01 00:00:00
# predicted_revenue_3_years_50                  68406.75             69025.88

# %%
df2_copy[df2_copy.accounts_group=='2024-05_Kenya_Lanterns_Kakamega_Sun King Boom EasyBuy'][["accounts_group", "frr_360", "frr_450", "frr_540", "cohort_age_backtesting", "current_horizon","date_uploaded", "predictions"]]#.to_csv("test.csv", index=False)
# Out:
#                                            accounts_group   frr_360   frr_450  \
# 153195  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ...  0.564007  0.672026
# 326430  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ...  0.564007       NaN
# 153074  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ...  0.564007  0.672026
# 321668  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ...  0.564007       NaN
#
#         frr_540  cohort_age_backtesting  current_horizon date_uploaded  \
# 153195      NaN                     450            450.0    2025-10-01
# 326430      NaN                     450            360.0    2025-10-01
# 153074      NaN                     450            450.0    2025-09-01
# 321668      NaN                     450            360.0    2025-09-01
#
#         predictions
# 153195     0.883211
# 326430     0.901629
# 153074     0.883211
# 321668     0.901629

# %%
(0.870390+0.877586)/2
# Out:
# 0.873988

# %%
df2= df2.drop(["current_horizon", "predicted_revenue_3_years_50"], axis=1, errors="ignore")
df2
# Out:
#                                            accounts_group  reg_month country  \
# 0       2016-01_Kenya_Lanterns_Kakamega_Sun King Pro E... 2016-01-01   Kenya
# 1       2016-02_Kenya_Lanterns_Bungoma_Sun King Pro Ea... 2016-02-01   Kenya
# 2       2016-02_Kenya_Lanterns_Kakamega_Sun King Pro E... 2016-02-01   Kenya
# 3       2016-03_Kenya_Lanterns_Bungoma_Sun King Pro Ea... 2016-03-01   Kenya
# 4       2016-03_Kenya_Lanterns_Kakamega_Sun King Pro E... 2016-03-01   Kenya
# ...                                                   ...        ...     ...
# 325044  2024-05_Zambia_SHS without TV_Mufulira_Sun Kin... 2024-05-01  Zambia
# 325045  2024-05_Zambia_SHS without TV_Mumbwa_Sun King ... 2024-05-01  Zambia
# 325046  2024-05_Zambia_SHS without TV_Ndola_Sun King H... 2024-05-01  Zambia
# 325047  2024-05_Zambia_SHS without TV_Serenje_Sun King... 2024-05-01  Zambia
# 325048  2024-05_Zambia_SHS without TV_Situmbeko_Sun Ki... 2024-05-01  Zambia
#
#          product_group       area             primary_product  count_units  \
# 0             Lanterns   Kakamega        Sun King Pro EasyBuy           57
# 1             Lanterns    Bungoma        Sun King Pro EasyBuy           18
# 2             Lanterns   Kakamega        Sun King Pro EasyBuy          287
# 3             Lanterns    Bungoma        Sun King Pro EasyBuy          114
# 4             Lanterns   Kakamega        Sun King Pro EasyBuy          142
# ...                ...        ...                         ...          ...
# 325044  SHS without TV   Mufulira  Sun King Home 500x EasyBuy           21
# 325045  SHS without TV     Mumbwa  Sun King Home 500x EasyBuy           11
# 325046  SHS without TV      Ndola  Sun King Home 500x EasyBuy           72
# 325047  SHS without TV    Serenje  Sun King Home 500x EasyBuy            7
# 325048  SHS without TV  Situmbeko  Sun King Home 500x EasyBuy           32
#
#         avg_planned_repayment_days  total_follow_on_revenue_current_usd  \
# 0                               77                          1542.804066
# 1                               77                           487.201284
# 2                               77                          7768.153806
# 3                               77                          3085.608132
# 4                               77                          3843.476796
# ...                            ...                                  ...
# 325044                         379                          4406.412463
# 325045                         381                          2316.291153
# 325046                         375                         14940.641195
# 325047                         381                          1474.003461
# 325048                         375                          6637.564968
#
#         total_follow_on_revenue  ...  age_in_months  exchange  \
# 0                      199500.0  ...            116    152.85
# 1                       63000.0  ...            115    152.85
# 2                     1004500.0  ...            115    152.85
# 3                      399000.0  ...            114    152.85
# 4                      497000.0  ...            114    152.85
# ...                         ...  ...            ...       ...
# 325044                 101700.0  ...             15     25.30
# 325045                  53460.0  ...             15     25.30
# 325046                 344830.0  ...             15     25.30
# 325047                  34020.0  ...             15     25.30
# 325048                 153195.0  ...             15     25.30
#
#         total_follow_on_revenue_usd_cal  total_follow_on_revenue_usd_final  \
# 0                             1305.2012                        1305.201200
# 1                              412.1688                         412.168800
# 2                             6571.8024                        6571.802400
# 3                             2610.4024                        2610.402400
# 4                             3251.5538                        3251.553800
# ...                                 ...                                ...
# 325044                        4019.7628                        3833.089845
# 325045                        2113.0435                        2014.916255
# 325046                       13629.6443                       12996.699816
# 325047                        1344.6640                        1282.219435
# 325048                        6055.1383                        5773.944925
#
#         avg_upfront_price_usd  avg_unlock_price_usd  backtesting_limit  \
# 0                         7.0                  30.0                360
# 1                         7.0                  30.0                360
# 2                         7.0                  30.0                360
# 3                         7.0                  30.0                360
# 4                         7.0                  30.0                360
# ...                       ...                   ...                ...
# 325044                   19.0                 201.0                360
# 325045                   19.0                 202.0                360
# 325046                   19.0                 199.0                360
# 325047                   19.0                 202.0                360
# 325048                   19.0                 199.0                360
#
#         cohort_age_backtesting  predictions  date_uploaded
# 0                          720     0.977491     2025-10-01
# 1                          720     0.912855     2025-10-01
# 2                          720     0.958276     2025-10-01
# 3                          720     0.928347     2025-10-01
# 4                          720     0.945235     2025-10-01
# ...                        ...          ...            ...
# 325044                     450     0.995204     2025-09-01
# 325045                     450     0.924074     2025-09-01
# 325046                     450     0.987860     2025-09-01
# 325047                     450     0.957965     2025-09-01
# 325048                     450     0.997138     2025-09-01
#
# [658501 rows x 91 columns]

# %%
df = df2.groupby(["accounts_group", "reg_month", "country", "product_group", "area", "primary_product", "count_units", "total_follow_on_revenue_current_usd", "date_uploaded"]).agg(
    predicted_frr_agg= ("predictions", "mean")
).reset_index()

# %%
df[df.accounts_group=='2024-05_Kenya_Lanterns_Kakamega_Sun King Boom EasyBuy']
# Out:
#                                            accounts_group  reg_month country  \
# 306085  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ... 2024-05-01   Kenya
# 306086  2024-05_Kenya_Lanterns_Kakamega_Sun King Boom ... 2024-05-01   Kenya
#
#        product_group      area        primary_product  count_units  \
# 306085      Lanterns  Kakamega  Sun King Boom EasyBuy         1360
# 306086      Lanterns  Kakamega  Sun King Boom EasyBuy         1360
#
#         total_follow_on_revenue_current_usd date_uploaded  predicted_frr_agg
# 306085                         85365.246144    2025-10-01            0.89242
# 306086                         85398.266724    2025-09-01            0.89242

# %%
df["predicted_revenue_3_years"] = np.round(df['predicted_frr_agg']*df['total_follow_on_revenue_current_usd'],2)

# %% [markdown]
# ## Visuals by Country

# %%
from matplotlib import pyplot as plt
import seaborn as sns

df_country = df.groupby(["country", "reg_month", "date_uploaded"]).agg(
    count_average=("count_units", lambda x: int(x.mean())),
    predicted_fr = ("predicted_revenue_3_years", "sum"),
    total_fr = ("total_follow_on_revenue_current_usd", "sum")
).reset_index()
df_country["predicted_frr_updated"] = df_country.predicted_fr/df_country.total_fr
df_country = df_country.drop(['total_fr', 'predicted_fr'], axis=1)
# products = ["Lanterns", "Phones", "SHS Entry-Level", "SHS with TV", "SHS without TV", "SHS Entry-Level Upgrade", "SHS with TV Upgrade"]
# df_country = df_country[df_country.product_group.isin(products)]
df_country

for country in ["Kenya", "Tanzania", "Nigeria", "Zambia", "Togo", "Uganda"]:
    plt.figure(figsize=(15, 6))
    sns.lineplot(data=df_country[(df_country.country==country) & (df_country.reg_month>="2023-01-01")], x="reg_month", y="predicted_frr_updated",\
                  hue="date_uploaded")
    # sns.lineplot(data=df_country, x="reg_month", y="frr_prediction_50")
    plt.xticks(rotation=45)
    plt.title(country)
    plt.show()

# %%
df_country[df_country["reg_month"]=="2024-05-01"]
# Out:
#               country  reg_month date_uploaded  count_average  \
# 36           Cameroon 2024-05-01    2025-09-01             20
# 37           Cameroon 2024-05-01    2025-10-01             20
# 199             India 2024-05-01    2025-09-01              5
# 200             India 2024-05-01    2025-10-01              5
# 405             Kenya 2024-05-01    2025-09-01             73
# 406             Kenya 2024-05-01    2025-10-01             73
# 446            Malawi 2024-05-01    2025-09-01            106
# 447            Malawi 2024-05-01    2025-10-01            106
# 517        Mozambique 2024-05-01    2025-09-01             27
# 518        Mozambique 2024-05-01    2025-10-01             27
# 702   Myanmar (Burma) 2024-05-01    2025-09-01              9
# 703   Myanmar (Burma) 2024-05-01    2025-10-01              9
# 885           Nigeria 2024-05-01    2025-09-01             27
# 886           Nigeria 2024-05-01    2025-10-01             27
# 898      South Africa 2024-05-01    2025-09-01             12
# 899      South Africa 2024-05-01    2025-10-01             12
# 1081         Tanzania 2024-05-01    2025-09-01             29
# 1082         Tanzania 2024-05-01    2025-10-01             28
# 1188             Togo 2024-05-01    2025-09-01            225
# 1189             Togo 2024-05-01    2025-10-01            225
# 1373           Uganda 2024-05-01    2025-09-01             10
# 1374           Uganda 2024-05-01    2025-10-01             10
# 1456           Zambia 2024-05-01    2025-09-01            135
# 1457           Zambia 2024-05-01    2025-10-01            135
#
#       predicted_frr_updated
# 36                 0.926610
# 37                 0.926610
# 199                0.813815
# 200                0.814847
# 405                0.853746
# 406                0.853940
# 446                0.977804
# 447                0.977804
# 517                0.798100
# 518                0.798100
# 702                0.997491
# 703                0.997491
# 885                0.928086
# 886                0.928100
# 898                0.990028
# 899                0.990028
# 1081               0.859689
# 1082               0.860603
# 1188               0.789385
# 1189               0.789385
# 1373               0.774784
# 1374               0.774784
# 1456               0.975642
# 1457               0.976067

# %%
0.851948 - 0.859237
# Out:
# -0.00728899999999999

# %% [markdown]
# ## Visuals by Country and Product

# %%
from matplotlib import pyplot as plt
import seaborn as sns

df_product = df.groupby(["country", "product_group","reg_month", "date_uploaded"]).agg(
    count_average=("count_units", lambda x: int(x.mean())),
    predicted_fr = ("predicted_revenue_3_years", "sum"),
    total_fr = ("total_follow_on_revenue_current_usd", "sum")
).reset_index()
df_product["predicted_frr_updated"] = df_product.predicted_fr/df_product.total_fr
df_product = df_product.drop(['total_fr', 'predicted_fr'], axis=1)
# products = ["Lanterns", "Phones", "SHS Entry-Level", "SHS with TV", "SHS without TV", "SHS Entry-Level Upgrade", "SHS with TV Upgrade"]
# df_product = df_product[df_product.product_group.isin(products)]
df_product

for product_group in ["Lanterns", "SHS Entry-Level", "SHS with TV"]:
    for country in ["Kenya", "Tanzania", "Nigeria", "Zambia", "Togo", "Uganda"]:
        plt.figure(figsize=(15, 6))
        sns.lineplot(data=df_product[(df_product.country==country) & (df_product.product_group==product_group) & (df_product.reg_month>="2023-01-01")], x="reg_month", y="predicted_frr_updated",\
                    hue="date_uploaded")
        # sns.lineplot(data=df_product, x="reg_month", y="frr_prediction_50")
        plt.xticks(rotation=45)
        plt.title(f"{country}--{product_group}")
        plt.show()

# %%
df_product[(df_product["reg_month"]=="2024-05-01") & (df_product.country=="Kenya") & (df_product.product_group=="Lanterns")]
# Out:
#     country product_group  reg_month date_uploaded  count_average  \
# 878   Kenya      Lanterns 2024-05-01    2025-09-01            433
# 879   Kenya      Lanterns 2024-05-01    2025-10-01            433
#
#      predicted_frr_updated
# 878               0.877409
# 879               0.877409

# %%
0.873753-0.867906
# Out:
# 0.005847000000000047

# %%
pivoted = df_product.pivot_table(
    index=["country", "product_group","reg_month",],
    columns="date_uploaded",
    values=["predicted_frr_updated", "count_average"]
).reset_index()
pivoted.columns = [
    str(c[0]) if c[1] == "" or pd.isna(c[1]) else f"{c[0]}_{c[1].date()}"
    for c in pivoted.columns.to_flat_index()
]
pivoted["reg_month"] = pd.to_datetime(pivoted["reg_month"])

pivoted["diff"] = pivoted["predicted_frr_updated_2025-10-01"] - pivoted["predicted_frr_updated_2025-09-01"]
pivoted.head()

backtestings = np.array([30, 60, 90, 180, 270, 360, 450, 540, 630, 720], dtype=int)
months = backtestings // 30

base_current = pd.to_datetime("2025-10-01")
base_prev = pd.to_datetime("2025-09-01")

backtesting_month_current = [base_current - pd.DateOffset(months=m+1) for m in months]
backtesting_month_prev = [base_prev - pd.DateOffset(months=m+2) for m in months]

data = {
    "Months": months,
    "backtesting_month_current": backtesting_month_current,
    "backtesting_month_prev": backtesting_month_prev,
    "backtesting_shift": backtestings,
}
backtestings_df = pd.DataFrame(data)

print(backtestings_df)

discrepancies = pd.merge(left=pivoted, right=backtestings_df, left_on="reg_month", right_on="backtesting_month_current", how="left")
discrepancies["backtesting_shift"] = discrepancies["backtesting_shift"].astype("Int64")
discrepancies = discrepancies[discrepancies.backtesting_shift.isin([450, 540, 630, 720])]

# discrepancies["diff"] = (discrepancies["predicted_frr_updated_2025-08"] - discrepancies["predicted_frr_updated_2025-07"]).round(4)*100
# Out:
#    Months backtesting_month_current backtesting_month_prev  backtesting_shift
# 0       1                2025-08-01             2025-06-01                 30
# 1       2                2025-07-01             2025-05-01                 60
# 2       3                2025-06-01             2025-04-01                 90
# 3       6                2025-03-01             2025-01-01                180
# 4       9                2024-12-01             2024-10-01                270
# 5      12                2024-09-01             2024-07-01                360
# 6      15                2024-06-01             2024-04-01                450
# 7      18                2024-03-01             2024-01-01                540
# 8      21                2023-12-01             2023-10-01                630
# 9      24                2023-09-01             2023-07-01                720

# %%
discrepancies_country = discrepancies.groupby(["country", "reg_month", "product_group", "backtesting_shift"]).agg(diff2=("diff", "mean")).reset_index()

# %% [markdown]
# ## DIffs at Backtesting shift

# %%
for product_group in ["Lanterns", "SHS Entry-Level", "SHS with TV"]:
    for country in ["Kenya", "Tanzania", "Nigeria", "Zambia", "Togo", "Uganda"]:
        plt.figure(figsize=(10, 6))
        plt.ylim((-0.03, 0.03))

        subset = discrepancies_country[
            (discrepancies_country.country == country) &
            (discrepancies_country.product_group == product_group)
        ]

        ax = sns.barplot(
            data=subset,
            x="backtesting_shift",
            y="diff2"
        )

        # add labels in percent (2 dp)
        for container in ax.containers:
            ax.bar_label(container, labels=[f"{v*100:.2f}%" for v in container.datavalues], fontsize=9)

        plt.xticks(rotation=45)
        plt.title(f"{product_group} — {country}")
        plt.show()

# %%
products = ["Lanterns", "Phones", "SHS Entry-Level", "SHS with TV", "SHS without TV", "SHS Entry-Level Upgrade", "SHS with TV Upgrade"]
discrepancies_country[discrepancies_country.product_group.isin(products)].groupby("country").agg(
    mean_diff = ("diff2", "mean"),
    min_diff = ("diff2", "min"),
    max_diff = ("diff2", "max")
).reset_index()
# Out:
#             country  mean_diff  min_diff  max_diff
# 0          Cameroon  -0.004511 -0.041873  0.014656
# 1             India  -0.003738 -0.006488 -0.001333
# 2             Kenya  -0.004288 -0.015000  0.003613
# 3            Malawi  -0.001059 -0.003234  0.000327
# 4        Mozambique  -0.011962 -0.062234  0.000432
# 5   Myanmar (Burma)   0.000479 -0.000441  0.001563
# 6           Nigeria  -0.001399 -0.009625  0.009085
# 7      South Africa  -0.008628 -0.024908  0.003853
# 8          Tanzania  -0.004208 -0.014127  0.007607
# 9              Togo   0.021003 -0.015660  0.043781
# 10           Uganda  -0.008163 -0.023481  0.019165
# 11           Zambia  -0.001215 -0.017473  0.010627
