# %%
from setup_notebook import setup_project_path
setup_project_path()
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_new_sep = pd.read_csv("../output/predictions_new_kpi_sep_360_days_2025-09-19.csv")
df_new_sep["date_uploaded"] = "2025-09-01"

df_new_aug = pd.read_csv("../output/predictions_new_kpi_aug_360_days_2025-09-19.csv")
df_new_aug["date_uploaded"] = "2025-08-01"
df_new_aug.head()
# Out:
#                                        pred_prim_key  \
# 0  2016-01_Kenya_Lanterns_Kakamega_Sun King Pro E...
# 1  2016-02_Kenya_Lanterns_Bungoma_Sun King Pro Ea...
# 2  2016-02_Kenya_Lanterns_Kakamega_Sun King Pro E...
# 3  2016-03_Kenya_Lanterns_Bungoma_Sun King Pro Ea...
# 4  2016-03_Kenya_Lanterns_Kakamega_Sun King Pro E...
#
#                                       accounts_group  count_units reg_month  \
# 0  2016-01_Kenya_Lanterns_Kakamega_Sun King Pro E...           57   2016-01
# 1  2016-02_Kenya_Lanterns_Bungoma_Sun King Pro Ea...           18   2016-02
# 2  2016-02_Kenya_Lanterns_Kakamega_Sun King Pro E...          287   2016-02
# 3  2016-03_Kenya_Lanterns_Bungoma_Sun King Pro Ea...          114   2016-03
# 4  2016-03_Kenya_Lanterns_Kakamega_Sun King Pro E...          142   2016-03
#
#   country      area       primary_product product_group  \
# 0   Kenya  Kakamega  Sun King Pro EasyBuy      Lanterns
# 1   Kenya   Bungoma  Sun King Pro EasyBuy      Lanterns
# 2   Kenya  Kakamega  Sun King Pro EasyBuy      Lanterns
# 3   Kenya   Bungoma  Sun King Pro EasyBuy      Lanterns
# 4   Kenya  Kakamega  Sun King Pro EasyBuy      Lanterns
#
#    backtesting_unit_age_days  frr_prediction_10  frr_prediction_50  \
# 0                        360           0.971373           0.984245
# 1                        360           0.892442           0.920153
# 2                        360           0.950737           0.961316
# 3                        360           0.913800           0.922764
# 4                        360           0.940154           0.945557
#
#    frr_prediction_80  predicted_revenue_3_years_10  \
# 0           0.973307                       1499.10
# 1           0.928462                        434.93
# 2           0.961045                       7387.75
# 3           0.948667                       2820.50
# 4           0.952192                       3614.58
#
#    predicted_revenue_3_years_50  predicted_revenue_3_years_80  \
# 0                       1518.97                       1502.09
# 1                        448.44                        452.49
# 2                       7469.96                       7467.85
# 3                       2848.17                       2928.12
# 4                       3635.35                       3660.86
#
#    total_follow_on_revenue_current_usd date_uploaded
# 0                          1543.281498    2025-08-01
# 1                           487.352052    2025-08-01
# 2                          7770.557718    2025-08-01
# 3                          3086.562996    2025-08-01
# 4                          3844.666188    2025-08-01

# %%
df_new_sep[df_new_sep['accounts_group']=='2024-05_Kenya_Lanterns_Kakamega_Sun King Pro EasyBuy'].T
# Out:
#                                                                                 153075
# pred_prim_key                        2024-05_Kenya_Lanterns_Kakamega_Sun King Pro E...
# accounts_group                       2024-05_Kenya_Lanterns_Kakamega_Sun King Pro E...
# count_units                                                                         58
# reg_month                                                                      2024-05
# country                                                                          Kenya
# area                                                                          Kakamega
# primary_product                                                   Sun King Pro EasyBuy
# product_group                                                                 Lanterns
# backtesting_unit_age_days                                                          360
# frr_prediction_10                                                             0.435029
# frr_prediction_50                                                             0.865867
# frr_prediction_80                                                             0.412607
# predicted_revenue_3_years_10                                                   1171.98
# predicted_revenue_3_years_50                                                   2332.67
# predicted_revenue_3_years_80                                                   1111.58
# total_follow_on_revenue_current_usd                                         2694.02753
# date_uploaded                                                               2025-09-01

# %%
df_new_aug[df_new_aug['accounts_group']=='2024-05_Kenya_Lanterns_Kakamega_Sun King Pro EasyBuy'].T
# Out:
#                                                                                 152812
# pred_prim_key                        2024-05_Kenya_Lanterns_Kakamega_Sun King Pro E...
# accounts_group                       2024-05_Kenya_Lanterns_Kakamega_Sun King Pro E...
# count_units                                                                         58
# reg_month                                                                      2024-05
# country                                                                          Kenya
# area                                                                          Kakamega
# primary_product                                                   Sun King Pro EasyBuy
# product_group                                                                 Lanterns
# backtesting_unit_age_days                                                          360
# frr_prediction_10                                                             0.209358
# frr_prediction_50                                                             0.875325
# frr_prediction_80                                                             0.287601
# predicted_revenue_3_years_10                                                    563.97
# predicted_revenue_3_years_50                                                   2357.97
# predicted_revenue_3_years_80                                                    774.75
# total_follow_on_revenue_current_usd                                        2693.819107
# date_uploaded                                                               2025-08-01

# %%
df_new_aug.backtesting_unit_age_days.unique()
# Out:
# array([360])

# %%
df = pd.concat([df_new_sep, df_new_aug])
print(df.shape)
df["date_uploaded"] = pd.to_datetime(df["date_uploaded"], format="%Y-%m-%d")
df["reg_month"] = pd.to_datetime(df["reg_month"], format="%Y-%m")
# Out:
# (332439, 17)

# %%
df2 = df.groupby(["country", "product_group","reg_month", "date_uploaded"]).agg(
    count_average=("count_units", lambda x: int(x.mean())),
    predicted_fr = ("predicted_revenue_3_years_50", "sum"),
    total_fr = ("total_follow_on_revenue_current_usd", "sum")
).reset_index()
df2["predicted_frr_updated"] = df2.predicted_fr/df2.total_fr
df2 = df2.drop(['total_fr', 'predicted_fr'], axis=1)
products = ["Lanterns", "Phones", "SHS Entry-Level", "SHS with TV", "SHS without TV", "SHS Entry-Level Upgrade", "SHS with TV Upgrade"]
df2 = df2[df2.product_group.isin(products)]
df2
# Out:
#        country    product_group  reg_month date_uploaded  count_average  \
# 25    Cameroon  SHS Entry-Level 2022-11-01    2025-08-01              3
# 26    Cameroon  SHS Entry-Level 2022-11-01    2025-09-01              3
# 27    Cameroon  SHS Entry-Level 2022-12-01    2025-08-01              5
# 28    Cameroon  SHS Entry-Level 2022-12-01    2025-09-01              5
# 29    Cameroon  SHS Entry-Level 2023-01-01    2025-08-01              4
# ...        ...              ...        ...           ...            ...
# 5923    Zambia   SHS without TV 2024-06-01    2025-08-01             46
# 5924    Zambia   SHS without TV 2024-06-01    2025-09-01             46
# 5925    Zambia   SHS without TV 2024-07-01    2025-08-01             44
# 5926    Zambia   SHS without TV 2024-07-01    2025-09-01             44
# 5927    Zambia   SHS without TV 2024-08-01    2025-09-01             48
#
#       predicted_frr_updated
# 25                 0.801780
# 26                 0.801780
# 27                 0.946246
# 28                 0.946246
# 29                 0.898509
# ...                     ...
# 5923               0.988428
# 5924               0.988428
# 5925               0.993539
# 5926               0.993463
# 5927               0.987685
#
# [4777 rows x 6 columns]

# %%
uad = 360
accounts_group = '2019-05_Kenya_Lanterns_' # Keep the underscore at the end.
df2[(df2['product_group']=='SHS with TV') & (df2['reg_month']=='2020-05-01') & (df2['country']=='Kenya')]
# Out:
#      country product_group  reg_month date_uploaded  count_average  \
# 1518   Kenya   SHS with TV 2020-05-01    2025-08-01              1
# 1519   Kenya   SHS with TV 2020-05-01    2025-09-01              1
#
#       predicted_frr_updated
# 1518               0.956075
# 1519               0.956073

# %%
df2
# Out:
#        country    product_group  reg_month date_uploaded  count_average  \
# 25    Cameroon  SHS Entry-Level 2022-11-01    2025-08-01              3
# 26    Cameroon  SHS Entry-Level 2022-11-01    2025-09-01              3
# 27    Cameroon  SHS Entry-Level 2022-12-01    2025-08-01              5
# 28    Cameroon  SHS Entry-Level 2022-12-01    2025-09-01              5
# 29    Cameroon  SHS Entry-Level 2023-01-01    2025-08-01              4
# ...        ...              ...        ...           ...            ...
# 5923    Zambia   SHS without TV 2024-06-01    2025-08-01             46
# 5924    Zambia   SHS without TV 2024-06-01    2025-09-01             46
# 5925    Zambia   SHS without TV 2024-07-01    2025-08-01             44
# 5926    Zambia   SHS without TV 2024-07-01    2025-09-01             44
# 5927    Zambia   SHS without TV 2024-08-01    2025-09-01             48
#
#       predicted_frr_updated
# 25                 0.801780
# 26                 0.801780
# 27                 0.946246
# 28                 0.946246
# 29                 0.898509
# ...                     ...
# 5923               0.988428
# 5924               0.988428
# 5925               0.993539
# 5926               0.993463
# 5927               0.987685
#
# [4777 rows x 6 columns]

# %%
for country in ["Kenya", "Tanzania", "Nigeria", "Zambia", "Togo", "Uganda"]:
    plt.figure(figsize=(15, 6))
    sns.lineplot(data=df2[(df2.country==country) & (df2.reg_month>="2022-01-01")], x="reg_month", y="predicted_frr_updated",\
                  hue="date_uploaded")
    # sns.lineplot(data=df2, x="reg_month", y="frr_prediction_50")
    plt.xticks(rotation=45)
    plt.title(country)
    plt.show()

# %%
pivoted = df2.pivot_table(
    index=["country", "product_group","reg_month",],
    columns="date_uploaded",
    values=["predicted_frr_updated", "count_average"]
).reset_index()
pivoted.columns = [
    str(c[0]) if c[1] == "" or pd.isna(c[1]) else f"{c[0]}_{c[1].date()}"
    for c in pivoted.columns.to_flat_index()
]
pivoted["reg_month"] = pd.to_datetime(pivoted["reg_month"])

pivoted["diff"] = pivoted["predicted_frr_updated_2025-09-01"] - pivoted["predicted_frr_updated_2025-08-01"]
pivoted.head()
# Out:
#     country    product_group  reg_month  count_average_2025-08-01  \
# 0  Cameroon  SHS Entry-Level 2022-11-01                       3.0
# 1  Cameroon  SHS Entry-Level 2022-12-01                       5.0
# 2  Cameroon  SHS Entry-Level 2023-01-01                       4.0
# 3  Cameroon  SHS Entry-Level 2023-02-01                       4.0
# 4  Cameroon  SHS Entry-Level 2023-03-01                       8.0
#
#    count_average_2025-09-01  predicted_frr_updated_2025-08-01  \
# 0                       3.0                          0.801780
# 1                       5.0                          0.946246
# 2                       4.0                          0.898509
# 3                       4.0                          0.971824
# 4                       8.0                          0.957891
#
#    predicted_frr_updated_2025-09-01  diff
# 0                          0.801780   0.0
# 1                          0.946246   0.0
# 2                          0.898509   0.0
# 3                          0.971824   0.0
# 4                          0.957891   0.0

# %%
backtestings = np.array([30, 60, 90, 180, 270, 360, 450, 540, 630, 720], dtype=int)
months = backtestings // 30

base_current = pd.to_datetime("2025-09-01")
base_prev = pd.to_datetime("2025-08-01")

backtesting_month_current = [base_current - pd.DateOffset(months=m+1) for m in months]
backtesting_month_prev = [base_prev - pd.DateOffset(months=m+2) for m in months]

data = {
    "Months": months,
    "backtesting_month_current": backtesting_month_current,
    "backtesting_month_prev": backtesting_month_prev,
    "backtesting_shift": backtestings,
}
backtestings_df = pd.DataFrame(data)

print(backtestings_df)
# Out:
#    Months backtesting_month_current backtesting_month_prev  backtesting_shift
# 0       1                2025-07-01             2025-05-01                 30
# 1       2                2025-06-01             2025-04-01                 60
# 2       3                2025-05-01             2025-03-01                 90
# 3       6                2025-02-01             2024-12-01                180
# 4       9                2024-11-01             2024-09-01                270
# 5      12                2024-08-01             2024-06-01                360
# 6      15                2024-05-01             2024-03-01                450
# 7      18                2024-02-01             2023-12-01                540
# 8      21                2023-11-01             2023-09-01                630
# 9      24                2023-08-01             2023-06-01                720

# %%
discrepancies = pd.merge(left=pivoted, right=backtestings_df, left_on="reg_month", right_on="backtesting_month_current", how="left")
discrepancies["backtesting_shift"] = discrepancies["backtesting_shift"].astype("Int64")
discrepancies = discrepancies[discrepancies.backtesting_shift.isin([450, 540, 630, 720])]

# discrepancies["diff"] = (discrepancies["predicted_frr_updated_2025-08"] - discrepancies["predicted_frr_updated_2025-07"]).round(4)*100

# %%
aa = discrepancies[discrepancies.country=="Kenya"]
aa[aa["diff"] == aa["diff"].max()]
# Out:
#     country        product_group  reg_month  count_average_2025-08-01  \
# 682   Kenya  SHS with TV Upgrade 2024-05-01                       3.0
#
#      count_average_2025-09-01  predicted_frr_updated_2025-08-01  \
# 682                       3.0                          0.779101
#
#      predicted_frr_updated_2025-09-01      diff  Months  \
# 682                          0.793158  0.014057    15.0
#
#     backtesting_month_current backtesting_month_prev  backtesting_shift
# 682                2024-05-01             2024-03-01                450

# %%
for country in ["Kenya", "Tanzania", "Nigeria", "Zambia", "Togo", "Uganda"]:
    plt.figure(figsize=(10, 6))
    plt.ylim((-0.03, 0.03))
    sns.barplot(data=discrepancies[discrepancies.country==country], x="backtesting_shift", y="diff")
    # sns.lineplot(data=df2, x="reg_month", y="frr_prediction_50")
    plt.xticks(rotation=45)
    plt.title(country)
    plt.show()

# %%
discrepancies[discrepancies.country.isin(["Kenya", "Nigeria", "Tanzania", "Uganda", "Zambia", "Togo"])].groupby("country").agg(
    mean_diff = ("diff", "mean"),
    min_diff = ("diff", "min"),
    max_diff = ("diff", "max"),
    median_diff = ("diff", "median"),
).reset_index()
# Out:
#     country  mean_diff  min_diff  max_diff  median_diff
# 0     Kenya  -0.004570 -0.017741  0.014057    -0.004554
# 1   Nigeria  -0.001921 -0.012717  0.005678    -0.000992
# 2  Tanzania  -0.005707 -0.028368  0.038068    -0.007108
# 3      Togo   0.021066 -0.018921  0.083197     0.010771
# 4    Uganda  -0.009396 -0.062795  0.041255    -0.009592
# 5    Zambia  -0.001175 -0.034125  0.010345    -0.000023
